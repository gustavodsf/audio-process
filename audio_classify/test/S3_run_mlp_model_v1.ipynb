# %%
import librosa
import numpy as np
from tensorflow import keras

# %load_ext autoreload
# %autoreload 2
# %run ./S0_util.ipynb

# %% [markdown]
# ### Sumário da Rede
# |Layer (typex)               | Output Shape        | Param   |
# | -------------------------- | ------------------- |---------|
# |conv2d (Conv2D)             | (None, 257, 22, 32) | 320     |
# |max_pooling2d (MaxPooling2D)| (None, 129, 11, 32) | 0       |
# |batch_normalization (BatchNo| (None, 129, 11, 32) | 128     |
# |conv2d_1 (Conv2D)           | (None, 127, 9, 32)  | 9248    |
# |max_pooling2d_1 (MaxPooling2| (None, 64, 5, 32)   | 0       |
# |batch_normalization_1 (Batch| (None, 64, 5, 32)   | 128     |
# |conv2d_2 (Conv2D)           | (None, 63, 4, 32)   | 4128    |
# |max_pooling2d_2 (MaxPooling2| (None, 32, 2, 32)   | 0       |
# |batch_normalization_2 (Batch| (None, 32, 2, 32)   | 128     |
# |flatten (Flatten)           | (None, 2048)        | 0       |
# |dense (Dense)               | (None, 64)          | 131136  |
# |dropout (Dropout)           | (None, 64)          | 0       |
# |dense_1 (Dense)             | (None, 2)           | 130     |
# ##### Batch 50 e EPOCHS 50

# %% [markdown]
# ### Conteúdo
# 1. F: MFCC [link](#mfcc)
# 1. F: MFCC,RMS [link](#mfcc_rms)
# 1. F: MFCC,RMS,ZCR [link](#mfcc_rms_zcr)
# 1. F: MFCC,RMS,ZCR,ONSET [link](#mfcc_rms_zcr_onset)
# 1. F: MFCC,RMS,ZCR,ONSET,CENTROID [link](#mfcc_rms_zcr_onset_centroid)
# 1. F: MFCC, MEL SPEC [link](#mfcc_mel_spec)
# 1. F: MEL SPEC [link](#mel_spec)
# 1. F: MEL SPEC,RMS [link](#mel_spec_rms)
# 1. F: MEL SPEC,RMS,ZCR [link](#mel_spec_rms_zcr)
# 1. F: MEL SPEC,RMS,ZCR,ONSET [link](#mel_spec_rms_zcr_onset)
# 1. F: MEL SPEC,RMS,ZCR,ONSET,CENTROID [link](#mel_spec_rms_zcr_onset_centroid)

# %% [markdown]
# <a id="mfcc"></a>
# #### MFCC
# > Foi gerado apenas `13` MFCC values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 13, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 13, 1)

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 13, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 13, 1)

# %% [markdown]
# <a id="mfcc_rms"></a>
# #### MFCC + RMS
# > Foi gerado apenas `13` MFCC values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 14, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 14, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb7c510dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 14, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 14, 1)

# %% [markdown]
# <a id="mfcc_rms_zcr"></a>
# #### MFCC + RMS + ZCR
# > Foi gerado apenas `13` MFCC values (Muito Utilizado para reconhecimento de padrão), no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 15, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 15, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb85213ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 15, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 15, 1)

# %% [markdown]
# <a id="mfcc_rms_zcr_onset"></a>
# #### MFCC + RMS + ZCR + ONSET
# > Foi gerado apenas `13` MFCC values (Muito Utilizado para reconhecimento de padrão), no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 16, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 16, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb6ec3c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 16, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 16, 1)

# %% [markdown]
# <a id="mfcc_rms_zcr_onset_centroid"></a>
# #### MFCC + RMS + ZCR + ONSET + CENTROID
# > Foi gerado apenas `13` MFCC values (Muito Utilizado para reconhecimento de padrão), no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset", "centroid"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset", "centroid"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 17, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 17, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb732bd820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset", "centroid"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc","rms", "zcr", "onset", "centroid"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 17, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 17, 1)

# %% [markdown]
# <a id="mfcc_mel_spec"></a>
# #### MFCC + MEL SPEC
# > Foi gerado apenas `13` MFCC values, Mel Spec foi gerado utilizando `20` faixas

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","mel_spec"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mfcc","mel_spec"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb5d0f8e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mfcc","mel_spec"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mfcc","mel_spec"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 33, 1)

# %% [markdown]
# <a id="mel_spec"></a>
# #### MEL SPEC
# > Mel Spec foi gerado utilizando 20 faixas

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mel_spec"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 20, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 20, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb64479e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mel_spec"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 20, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 20, 1)

# %% [markdown]
# <a id="mels_spec_rms"></a>
# #### MEL SPEC + RMS
# > Mel Spec foi gerado utilizando `20` faixas

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 21, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 21, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb4f1af550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 21, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 21, 1)

# %% [markdown]
# <a id="mel_spec_rms_zcr"></a>
# #### MEL SPEC + RMS + ZCR
# > Mel Spec foi gerado utilizando `20` faixas, no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 22, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 22, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb4d766040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 22, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 22, 1)

# %% [markdown]
# <a id="mel_spec_rms_zcr_onset"></a>
# #### MEL SPEC + RMS + ZCR + ONSET
# > Mel Spec foi gerado utilizando `20` faixas, no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 23, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 23, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb68064790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 23, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 23, 1)

# %% [markdown]
# <a id="mel_spec_rms_zcr_onset_centroid"></a>
# ####  MEL SPEC + RMS + ZCR + ONSET + CENTROID
# > Mel Spec foi gerado utilizando `20` faixas, no ZCR foi adicionado uma constante

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset", "centroid"], '../data/globo/8701320.wav')
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset", "centroid"],'../data/globo/949809.wav')
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 259, 24, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 259, 24, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbb68740dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset", "centroid"], "../data/globo/7822663.wav")
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms", "zcr", "onset", "centroid"],"../data/globo/7957359.wav")
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 259, 24, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 259, 24, 1)
