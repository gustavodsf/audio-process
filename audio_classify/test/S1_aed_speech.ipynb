# %% [markdown]
# ### Analise Exploratório da Fala
#  Objetivo: Verificar o comportamento das __features__ do áudio quando é uma fala.

# %% [markdown]
# #### Conteúdo
# 1. [Waveplot](#waveplot)
# 1. [Chroma](#chroma)
# 1. [Energy](#energy)
# 1. [Beat Track](#beat_track)
# 1. [PLP](#plp)
# 1. [MFCC](#mfcc)
# 1. [Energy II](#energy_v2)
# 1. [Spectral Centroid](#spectral_centroid)
# 1. [Zero Crossing Rate](#zero_crossing_rate)

# %% [markdown]
# * Roda o notebook que possui funções compartilhadas.

# %%
# %load_ext autoreload
# %autoreload 2
# %run ./S0_util.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# * Caminho dos arquivos que serão utilizados para análise

# %%
#Arquivos favorita
speech1 = "../data/speechs/sample-50.wav"
speech2 = "../data/speechs/sample-2791.wav"
speech3 = "../data/speechs/sample-4525.wav"
speech4 = "../data/speechs/sample-6573.wav"
#Arquivos Grito + Inglês 
speech5 = "../data/speechs/sample-6729.wav"

# %% [markdown]
# * Abrindo os arquivos exemplos

# %%
audio_speech1, _ = librosa.load(speech1, sr=SAMPLE_RATE)
audio_speech2, _ = librosa.load(speech2, sr=SAMPLE_RATE)
audio_speech3, _ = librosa.load(speech3, sr=SAMPLE_RATE)
audio_speech4, _ = librosa.load(speech4, sr=SAMPLE_RATE)
audio_speech5, _ = librosa.load(speech5, sr=SAMPLE_RATE)

del speech1
del speech2
del speech3
del speech4
del speech5

# %% [markdown]
# <a id="waveplot"> </a>
# ### Waveplot

# %% [markdown]
# * Sample 50 (Português)

# %%
my_wave_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_wave_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_wave_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_wave_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_wave_plot(audio_speech5)

# %% [markdown]
# <a id="chroma"> </a>
# #### Chroma

# %% [markdown]
# A **chroma vector** ([Wikipedia](https://en.wikipedia.org/wiki/Chroma_feature)) (FMP, p. 123) é um vetor de característico de 12 elementos que indica quanta energia de cada classe de tom, {C, C #, Ré, Ré #, E, ..., B}, está presente no sinal.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_chroma_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_chroma_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_chroma_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_chroma_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_chroma_plot(audio_speech5)

# %% [markdown]
# **Conlusão**: Não foi possível observar um  classe pitch predominante, dado que a varição de energia é muito grande, entre as próprias aberturas.

# %% [markdown]
# <a id="energy"> </a>
# #### Energy

# %% [markdown]
# A **energia** ([Wikipedia](https://en.wikipedia.org/wiki/Energy_(signal_processing%29); FMP, p. 66) de um sinal corresponde à magnitude total do sinal. Para sinais de áudio, isso corresponde aproximadamente ao nível de volume do sinal. A energia em um sinal é definida como
#
# $$ \sum_n \left| x(n) \right|^2 $$
#
# A **raiz da energia média quadrática (RMSE)** de um sinal é definido por:
#
# $$ \sqrt{ \frac{1}{N} \sum_n \left| x(n) \right|^2 } $$

# %% [markdown]
# * Sample 50 (Português)

# %%
my_energy_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_energy_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_energy_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_energy_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_energy_plot(audio_speech5)

# %% [markdown]
# **Conlusão**: se percebe que não existe uma condição predominante, apenas que durante a evolução do sinal existe pontos com baixa energia.

# %% [markdown]
# <a id="beat_track"> </a>
# #### Beat_TracK

# %% [markdown]
# Calcule o erro entre os tempos de batida estimados e alguma lista de referência de localizações de batidas. Além disso, muitas métricas comparam as sequências de batidas em diferentes níveis métricos para lidar com a ambigüidade do andamento.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_beat_track_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_beat_track_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_beat_track_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_beat_track_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_beat_track_plot(audio_speech5)

# %% [markdown]
# <a id="plp"> </a>
# #### PLP

# %% [markdown]
# Este método pode ser preferido em vez do método beat_track quando se espera que o `tempo` varie significativamente ao longo do sinal.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_plp_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_plp_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_plp_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_plp_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_plp_plot(audio_speech5)

# %% [markdown]
# <a id="mfcc"></a>
# #### Mel Frequency Cepstral Coefficients (MFCCs)

# %% [markdown]
# Calcule o erro entre os tempos de batida estimados e alguma lista de referência de localizações de batidas. Além disso, muitas métricas comparam as sequências de batidas em diferentes níveis métricos para lidar com a ambigüidade do andamento. O primeiro MFCC, o 0º coeficiente, não transmite informações relevantes para a forma geral do espectro. Ele apenas transmite um deslocamento constante, ou seja, adicionando um valor constante a todo o espectro. Portanto, muitos praticantes descartam o primeiro MFCC ao realizar a classificação. Por enquanto, usaremos os MFCCs como estão.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_mfcc_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_mfcc_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_mfcc_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_mfcc_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_mfcc_plot(audio_speech5)

# %% [markdown]
# <a id="energy_v2"></a>
# #### Energy II

# %% [markdown]
# * Sample 50 (Português)

# %%
my_novelty_energy_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_novelty_energy_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_novelty_energy_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_novelty_energy_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_novelty_energy_plot(audio_speech5)

# %% [markdown]
# <a id="spectral_centroid"></a>
# #### Spectral Centroid

# %% [markdown]
# O **centróide espectral** ([Wikipedia](https://en.wikipedia.org/wiki/Spectral_centroid)) indica em qual frequência a energia de um espectro está centrada. Isso é como uma média ponderada:
#
# $$ f_c = \ frac {\ sum_k S (k) f (k)} {\ sum_k S (k)} $$
#
# onde $ S (k) $ é a magnitude espectral na frequência bin $ k $, $ f (k) $ é a frequência na bin $ k $.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_spectral_centroid_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_spectral_centroid_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_spectral_centroid_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_spectral_centroid_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_spectral_centroid_plot(audio_speech5)

# %% [markdown]
# <a id="zero_crossing_rate"></a>
# #### Zero Crossing Rate

# %% [markdown]
# A [Zero Crossing Rate](https://en.wikipedia.org/wiki/Zero-crossing_rate) indica o número de vezes que um sinal cruza o eixo horizontal.

# %% [markdown]
# * Sample 50 (Português)

# %%
my_zero_cross_plot(audio_speech1)

# %% [markdown]
# * Sample 2791 (Português)

# %%
my_zero_cross_plot(audio_speech2)

# %% [markdown]
# * Sample 4525 (Português)

# %%
my_zero_cross_plot(audio_speech3)

# %% [markdown]
# * Sample 6573 (Português)

# %%
my_zero_cross_plot(audio_speech4)

# %% [markdown]
# * Sample 6729 (Inglês + Grito)

# %%
my_zero_cross_plot(audio_speech5)
