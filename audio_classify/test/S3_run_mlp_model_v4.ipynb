# %% [markdown]
# ### Criação do modelo:
# * Segmento igual a 3 segundos
# * voltamos o hop length e fram length para o padrão de 512 e 2048
# * voltamos a rede convolucional para o padrão de (32,32,32,64,2)
# * agora treinamos um modelo para a base de dados inteiras e suas partes

# %%
import librosa
import numpy as np
from tensorflow import keras

# %load_ext autoreload
# %autoreload 2
# %run ./S0_util.ipynb

# %% [markdown]
# ### Sumário
# 1. Mel Spec + RMS (Base Inteira)[link](#mel_spec_rms_old_yt)
# 1. Mel Spec + Centroid (Base Inteira)[link](#mel_spec_centroid_old_yt)
# 1. Mel Spec + Onset (Base Inteira)[link](#mel_spec_onset_old_yt)
# 1. Mel Spec + RMS + Centroid + Onset (Base Inteira)[link](#mel_spec_rmse_onset_centroid_odl_yt)
# 1. Mel Spec + RMS (Dados Antigo)[link](#mel_spec_rms)
# 1. Mel Spec + Centroid (Dados Antigo)[link](#mel_spec_centroid)
# 1. Mel Spec + Onset (Dados Antigo)[link](#mel_spec_onset)
# 1. Mel Spec + RMS + Centroid + Onset (Dados Antigo)[link](#mel_spec_rmse_onset_centroid)
# 1. Mel Spec + RMS (Youtube)[link](#mel_spec_rms_yt)
# 1. Mel Spec + Centroid (Youtube)[link](#mel_spec_centroid_yt)
# 1. Mel Spec + Onset (Youtube)[link](#mel_spec_onset_yt)
# 1. Mel Spec + RMS + Centroid + Onset (Youtube)[link](#mel_spec_rmse_onset_centroid_yt)

# %% [markdown]
# <a id="mfcc_rms_old_yt"></a>
# #### MEL SPEC + rms (Todoas as Bases de Dados)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], '../data/globo/8701320.wav', ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],'../data/globo/949809.wav', ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], "../data/globo/7822663.wav", ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],"../data/globo/7957359.wav", ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_centroid_old_yt"></a>
# #### MEL SPEC + centroid (Todoas as Bases de Dados)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], '../data/globo/8701320.wav', ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],'../data/globo/949809.wav', ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3ea1b9160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], "../data/globo/7822663.wav", ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],"../data/globo/7957359.wav", ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_onset_old_yt"></a>
# #### MEL SPEC + onset (Todoas as Bases de Dados)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], '../data/globo/8701320.wav', ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],'../data/globo/949809.wav', ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3c7545c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], "../data/globo/7822663.wav", ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],"../data/globo/7957359.wav", ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_rmse_onset_centroid_old_yt"></a>
# #### MEL SPEC + rmse + onset + centroid (Todas as Bases de Dados)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], '../data/globo/8701320.wav', ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],'../data/globo/949809.wav', ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 35, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3ea1b4310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], "../data/globo/7822663.wav", ["old_yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],"../data/globo/7957359.wav", ["old_yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 35, 1)

# %% [markdown]
# <a id="mel_spec_rms"></a>
# #### MEL SPEC + rms (Dados Antigos)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], '../data/globo/8701320.wav', [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],'../data/globo/949809.wav', [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3c7fbb940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], "../data/globo/7822663.wav", [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],"../data/globo/7957359.wav", [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_centroid"></a>
# #### MEL SPEC + centroid (Dados Antigos)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], '../data/globo/8701320.wav', [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],'../data/globo/949809.wav', [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3aba9e430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], "../data/globo/7822663.wav", [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],"../data/globo/7957359.wav", [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_onset"></a>
# #### MEL SPEC + onset (Dados Antigos)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], '../data/globo/8701320.wav', [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],'../data/globo/949809.wav', [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3b1783940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], "../data/globo/7822663.wav", [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],"../data/globo/7957359.wav", [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_rmse_onset_centroid"></a>
# #### MEL SPEC + rmse + onset + centroid (Dados Antigos)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], '../data/globo/8701320.wav', [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],'../data/globo/949809.wav', [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 35, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb39a519790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], "../data/globo/7822663.wav", [])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],"../data/globo/7957359.wav", [])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 35, 1)

# %% [markdown]
# <a id="mel_spec_rms_yt"></a>
# #### MEL SPEC + rms (Youtube)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], '../data/globo/8701320.wav', ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],'../data/globo/949809.wav', ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb3a10915e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","rms"], "../data/globo/7822663.wav", ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","rms"],"../data/globo/7957359.wav", ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_centroid_yt"></a>
# #### MEL SPEC + centroid (Youtube)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], '../data/globo/8701320.wav', ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],'../data/globo/949809.wav', ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb389762c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","centroid"], "../data/globo/7822663.wav", ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","centroid"],"../data/globo/7957359.wav", ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_onset_yt"></a>
# #### MEL SPEC + onset (Youtube)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], '../data/globo/8701320.wav', ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],'../data/globo/949809.wav', ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 33, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb390dc3af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec","onset"], "../data/globo/7822663.wav", ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec","onset"],"../data/globo/7957359.wav", ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 33, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 33, 1)

# %% [markdown]
# <a id="mel_spec_rmse_onset_centroid_yt"></a>
# #### MEL SPEC + rmse + onset + centroid (Youtube)
# > Foi gerado apenas `32` MEL Spectogram values (Muito Utilizado para reconhecimento de padrão)

# %% [markdown]
# * Novela: A Favorita

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], '../data/globo/8701320.wav', ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],'../data/globo/949809.wav', ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (20, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (239, 130, 35, 1)
# WARNING:tensorflow:5 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb375dafca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# * Novela: Órfões da Terra

# %%
print("Abertura".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"], "../data/globo/7822663.wav", ["yt"])
print("Bloco1".center(20, '*'))
run_model(["mel_spec", "rms", "onset", "centroid"],"../data/globo/7957359.wav", ["yt"])
# Out:
# ******Abertura******
# SAMPLE SHAPE: (22, 130, 35, 1)
# *******Bloco1*******
# SAMPLE SHAPE: (203, 130, 35, 1)
